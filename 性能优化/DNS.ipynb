# %% [markdown]
# 1、清除浏览器 DNS 缓存
# • 清除 DNS 缓存：chrome://net-internals/#dns
# • 有时候也需要同时清除套接字缓存池：chrome://net-internals/#socket
#
#
#
#
# • 清除系统 DNS缓存
# 1 #在 Windows 中查看 DNS 缓存记录
# 2 ipconfig /displaydns w
# 3
# 4 #在 Windows 中清除 DNS 缓存记录
# 5 ipconfig /flushdns
# 6
# 7 #在 macos 中清除 DNS 缓存记录
# sudo killall -HUP mDNSResponder
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 更多 DNS解析优化
# 1. 延长 DNS缓存时间
#
# 2. 尽可能使用A或 AAAA 记录代替 CNAME
#
# 3. 使用 CDN 加速域名
# 4. 自己搭建 DNS服务
