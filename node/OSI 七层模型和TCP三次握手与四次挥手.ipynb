# %% [markdown]
# 🧱 OSI 七层结构（自上而下）
#
# | 层级 | 名称    | 英文名称               | 作用说明                           |
# | -- | ----- | ------------------ | ------------------------------ |
# | 7  | 应用层   | Application Layer  | 面向用户，提供网络服务（如 HTTP、FTP、SMTP 等） |
# | 6  | 表示层   | Presentation Layer | 数据格式转换、加解密、压缩（如 JPEG、MP4、SSL）  |
# | 5  | 会话层   | Session Layer      | 建立、管理和终止会话（如登录验证）,控制网络的链接与建立  和终止            |
# | 4  | 传输层   | Transport Layer    | 提供可靠数据传输（如 TCP、UDP）            |
# | 3  | 网络层   | Network Layer      | 路由选择与逻辑地址（如 IP、ICMP） 通过路由寻找网络          |
# | 2  | 数据链路层 | Data Link Layer    | 物理寻址和差错检测（如 MAC 地址、以太网）        |
# | 1  | 物理层   | Physical Layer     | 传输比特流，定义电压、电缆、网卡等物理设备          |

# %% [markdown]
# TCP三次握手与四次挥手
#
#
#
#
# 握手的时候服务端合并了请求和响应   导致只有三次
# 断开连接不能合并的原因   是因为  一个服务端会服务于多个客户端,  断开的时候并不能保证服务端把数据传输完了
#
# TCP 三次握手（Three-Way Handshake）
# ````lua
# 客户端                          服务器
#   | -------- SYN(x) -------->   |
#   | <---- SYN(y), ACK(x+1) ---- |
#   | -------- ACK(y+1) ------->  |
#   |        连接建立完成         |
#
# ````
#
#
#
# TCP 四次挥手（Four-Way Handshake）
# ````lua
# 客户端                          服务器
#   | -------- FIN(u) -------->   |
#   | <-------- ACK(u+1) -------- |
#   |                             |（此时服务器可能还有数据未发完）
#   | <-------- FIN(v) ---------- |
#   | -------- ACK(v+1) --------> |
#   |        连接断开完成         |
#
# ````

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)   ![image-4.png](attachment:image-4.png)
