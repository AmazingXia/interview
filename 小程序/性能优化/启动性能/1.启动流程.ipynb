# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. 环境准备
#   - 运行环境
#   - 小程序先关信息准备
#   - 代码包准备
#
# 2. 逻辑层代码注入
#
# 3. 视图层代码注入
#
#
# 4. 首次渲染
#   如果开启了「初始渲染缓存」，「首页渲染」可以直接使用缓存完成，不依赖逻辑层的初始数据，降低启动耗时。
#   以 Page.onReady 事件触发标志小程序启动过程完成
#
# 5. 首屏内容展示
