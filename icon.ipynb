# %% [markdown]
# #### ✅ 状态/反馈类图标
#
# | 图标 | 名称               | 场景        |
# | -- | ---------------- | --------- |
# | ✅  | `success`        | 操作成功提示    |
# | ⚠️ | `warning`        | 风险提醒、警告框  |
# | ❌  | `error` / `fail` | 失败提示      |
# | ℹ️ | `info`           | 帮助说明、信息提示 |
# | ⏳  | `loading`        | 加载中转圈     |
# | 💡 | `tip` / `idea`   | 小贴士、建议    |
#
# #### ✅ 文件/格式类图标
#
#
# | 图标 | 名称           | 使用场景     |
# | -- | ------------ | -------- |
# | 📄 | `document`   | 通用文档     |
# | 📑 | `pdf`        | PDF 文件上传 |
# | 📊 | `excel`      | 表格、统计数据  |
# | 📋 | `clipboard`  | 复制、粘贴    |
# | 📎 | `attachment` | 附件、文件上传  |
#
#
# #### ✅ 导航/交互类图标
#
# | 图标 | 名称                   | 场景          |
# | -- | -------------------- | ----------- |
# | ⬅️ | `arrow-left`         | 返回、上一步      |
# | ➡️ | `arrow-right`        | 下一步、详情展开    |
# | ⬆️ | `arrow-up`           | 上移、收起       |
# | ⬇️ | `arrow-down`         | 下拉、展开菜单     |
# | ☰  | `menu` / `hamburger` | 菜单折叠按钮（移动端） |
# | 🔽 | `dropdown`           | 下拉列表图标      |
# | 🔼 | `collapse`           | 折叠列表图标      |
#
#
# #### ✅ 媒体/预览类图标
#
# | 图标  | 名称       | 场景        |
# | --- | -------- | --------- |
# | 📷  | `camera` | 拍照、上传图片   |
# | 🖼️ | `image`  | 图片预览、图库   |
# | 🎬  | `video`  | 视频文件、播放视频 |
# | ▶️  | `play`   | 播放按钮      |
# | ⏸️  | `pause`  | 暂停按钮      |
# | ⏹️  | `stop`   | 停止播放      |
# | 🔊  | `volume` | 音量设置      |
# | 🔇  | `mute`   | 静音状态      |
#
# #### ✅ 电商/业务类图标
#
# | 图标 | 名称                   | 场景         |
# | -- | -------------------- | ---------- |
# | 🛒 | `shopping-cart`      | 电商购物车      |
# | 💳 | `credit-card`        | 支付信息、绑定银行卡 |
# | 📦 | `box` / `package`    | 物流、商品包裹    |
# | 💰 | `money` / `currency` | 价格、金额、结算页面 |
# | 📈 | `chart-up`           | 数据增长、营收增长  |
# | 📉 | `chart-down`         | 数据下降、风险提示  |
# | 🧾 | `bill` / `invoice`   | 账单、交易记录    |
# | 🧮 | `calculator`         | 计算器、财务计算   |
#
# #### ✅ 用户/身份类图标
#
# | 图标  | 名称                   | 使用场景        |
# | --- | -------------------- | ----------- |
# | 👤  | `user`               | 用户中心、登录用户信息 |
# | 👥  | `users`              | 用户管理、团队成员   |
# | 🆔  | `id-card`            | 用户详情、身份认证   |
# | 📨  | `message` / `mail`   | 消息通知、邮箱     |
# | 🔔  | `notification`       | 通知提醒、消息中心   |
# | 📞  | `phone`              | 联系方式、客服入口   |
# | 🛡️ | `shield`             | 权限控制、安全设置   |
# | 🧾  | `profile` / `report` | 报告、履历、用户档案  |
#
#
#
# ### ✅ 系统/界面操作类图标
#
# | 图标  | 名称/Unicode              | 典型使用场景      |
# | --- | ----------------------- | ----------- |
# | 🏠  | `home`                  | 首页按钮、导航栏主入口 |
# | 🧭  | `dashboard` / `compass` | 控制台、主面板     |
# | ⚙️  | `settings`              | 系统设置、用户设置入口 |
# | 🔒  | `lock`                  | 密码、隐私、加密内容  |
# | 🔓  | `unlock`                | 公开、权限已开启    |
# | ⏰   | `clock`                 | 时间选择、任务提醒   |
# | 📅  | `calendar`              | 日期选择、计划排程   |
# | 🗂️ | `folder`                | 文件夹列表、分类管理  |
# | 📁  | `open-folder`           | 展开文件夹内容     |
# | 📄  | `file`                  | 单个文档、资源文件   |
# | 🗑️ | `delete` / `trash`      | 删除操作按钮      |
# | ✏️  | `edit` / `pencil`       | 编辑按钮        |
# | ➕   | `add` / `plus`          | 添加按钮、新建元素   |
# | ➖   | `minus` / `remove`      | 减少、移除、收起    |
# | 🔍  | `search`                | 搜索栏按钮、放大镜图标 |
# | ⏳   | `loading` / `hourglass` | 加载中、等待状态    |
# | ✅   | `check`                 | 成功、勾选、验证通过  |
# | ❌   | `close` / `x`           | 关闭弹窗、取消、失败  |
# | 🚫  | `forbidden` / `ban`     | 禁用、禁止访问     |
# | 🔁  | `refresh` / `reload`    | 刷新页面、重试操作   |
# | 🔄  | `sync`                  | 同步状态、更新状态   |
